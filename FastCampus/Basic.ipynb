# %%
import pandas as pd

# %% [markdown]
# ### Series 데이터 만들기

# %%
a = [1,2,3,4]
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ### DataFrame 데이터 만들기 ( by List )

# %%
company = [['삼성',2000,'스마트폰'],
          ['현대',1000,'자동차'],
           ['네이버',5000,'포털'], 
          ]

# %%
df = pd.DataFrame(company)

# %%
df
# Out:
#      0     1     2
# 0   삼성  2000  스마트폰
# 1   현대  1000   자동차
# 2  네이버  5000    포털

# %% [markdown]
# ### 제목 컬럼 만들기

# %%
df.columns = ['기업명','매출액','업종']

# %%
df
# Out:
#    기업명   매출액    업종
# 0   삼성  2000  스마트폰
# 1   현대  1000   자동차
# 2  네이버  5000    포털

# %% [markdown]
# ### DataFrame 데이터 만들기 ( by Dict )

# %%
company2 = {"기업명" : ['삼성','현대','네이버'],
           "매출액" : [2000,1000,500],
            "업종" : ['스마트폰','자동차','포털']
           }

# %%
df2 = pd.DataFrame(company2)

# %%
df2
# Out:
#    기업명   매출액    업종
# 0   삼성  2000  스마트폰
# 1   현대  1000   자동차
# 2  네이버   500    포털

# %% [markdown]
# ### index를 특정 column으로 지정하기

# %%
df2.index = df2['기업명']

# %%
df2
# Out:
#      기업명   매출액    업종
# 기업명
# 삼성    삼성  2000  스마트폰
# 현대    현대  1000   자동차
# 네이버  네이버   500    포털

# %% [markdown]
# ### 해당 컬럼 데이터 가져오기

# %%
df["기업명"]
# Out:
# 0     삼성
# 1     현대
# 2    네이버
# Name: 기업명, dtype: object

# %% [markdown]
# ### CSV 파일 읽어오기

# %%
df3 = pd.read_csv("csv_example.csv")
df3
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306         ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %%
df2.columns
# Out:
# Index(['기업명', '매출액', '업종'], dtype='object')

# %% [markdown]
# ### 컬럼 명 바꾸기

# %%
new_columns = ["company name","earning","type"]
df2.columns = new_columns

# %%
df2
# Out:
#     company name  earning  type
# 기업명
# 삼성            삼성     2000  스마트폰
# 현대            현대     1000   자동차
# 네이버          네이버      500    포털

# %% [markdown]
# ### 인덱스 출력하기

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=1310, step=1)

# %% [markdown]
# ### 주요 메서드

# %% [markdown]
# ### method - info

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stage Name     1310 non-null   object
#  1   Full Name      1304 non-null   object
#  2   Korean Name    1304 non-null   object
#  3   K. Stage Name  1309 non-null   object
#  4   Date of Birth  1310 non-null   object
#  5   Group          1219 non-null   object
#  6   Country        1310 non-null   object
#  7   Birthplace     689 non-null    object
#  8   Other Group    122 non-null    object
#  9   Gender         1310 non-null   object
# dtypes: object(10)
# memory usage: 102.5+ KB

# %% [markdown]
# ### method - describe

# %%
df3.describe()
# Out:
#        Stage Name  Full Name Korean Name K. Stage Name Date of Birth Group  \
# count        1310       1304        1304          1309          1310  1219
# unique       1135       1251        1241          1082          1181   208
# top         Yujin  Kim Sohee         박수영            지수    1994-01-18   NCT
# freq            4          3           3             5             3    18
#
#             Country Birthplace     Other Group Gender
# count          1310        689             122   1310
# unique           12        135              55      2
# top     South Korea      Seoul  Super Junior-M      M
# freq           1204        188               6    676

# %%
df3.head()
# Out:
#   Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0        A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1        Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2       Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3       AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4       Ahra        Go Ahra         고아라            아라    2001-02-21
#
#        Group      Country Birthplace Other Group Gender
# 0  Limitless  South Korea        NaN         NaN      M
# 1        VAV  South Korea        NaN         NaN      M
# 2    Hashtag  South Korea      Daegu         NaN      F
# 3   MOMOLAND  South Korea      Wonju         NaN      F
# 4   Favorite  South Korea      Yeosu         NaN      F

# %%
df3.tail()
# Out:
#      Stage Name    Full Name Korean Name K. Stage Name Date of Birth  \
# 1305        Ziu  Park Heejun         박희준            지우    1997-06-16
# 1306         ZN    Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa   Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho     Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny    Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# 1305           VAV  South Korea        NaN         NaN      M
# 1306        LABOUM  South Korea    Bucheon       UNI.T      F
# 1307       Weeekly  South Korea        NaN         NaN      F
# 1308           SF9  South Korea        NaN         NaN      M
# 1309  Ladies' Code  South Korea    Gwangju         NaN      F

# %%
df3.head(3)
# Out:
#   Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0        A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1        Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2       Aeji      Kwon Aeji         권애지            애지    1999-10-25
#
#        Group      Country Birthplace Other Group Gender
# 0  Limitless  South Korea        NaN         NaN      M
# 1        VAV  South Korea        NaN         NaN      M
# 2    Hashtag  South Korea      Daegu         NaN      F

# %% [markdown]
# ### 정렬하기

# %% [markdown]
# ### 인덱스로 정렬

# %%
df3.sort_index()
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306         ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %% [markdown]
# ### Column 기준으로 정렬

# %%
df3.sort_values(by="Stage Name")
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1304       Zico       Woo Jiho         우지호            지코    1992-09-14
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %% [markdown]
# ### 소팅 기준을 두개 줄 수 있음

# %%
df3.sort_values(by=["Stage Name","Group"])
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1304       Zico       Woo Jiho         우지호            지코    1992-09-14
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %% [markdown]
# ### 컬럼 선택

# %%
df['기업명']
# Out:
# 0     삼성
# 1     현대
# 2    네이버
# Name: 기업명, dtype: object
